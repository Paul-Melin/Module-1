# %%
import json
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')
response.status_code
results = response.json()

import pandas as pd
data = pd.DataFrame(results)
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/359510760.py in <module>
#       1 import json
# ----> 2 import requests
#       3
#       4 response = requests.get('https://jsonplaceholder.typicode.com/todos')
#       5 response.status_code
#
# ModuleNotFoundError: No module named 'requests'

# %%
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/2193030176.py in <module>
# ----> 1 print(response.status_code)
#
# NameError: name 'response' is not defined

# %%
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/3238143988.py in <module>
# ----> 1 response = requests.get('https://api.github.com/events')
#       2 data = pd.DataFrame(response.json())
#       3 data.head(10)
#
# NameError: name 'requests' is not defined

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened=pd.DataFrame(dict(data[column])).transpose()
        columns=[str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)


flat.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/1387045676.py in <module>
#       9 nested_columns = ['actor', 'org', 'payload', 'repo']
#      10
# ---> 11 flat = flatten(data, nested_columns)
#      12
#      13
#
# NameError: name 'data' is not defined

# %%
results=response.json()
flattened_data=pd.json_normalize(results)
flattened_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/3066557940.py in <module>
# ----> 1 results=response.json()
#       2 flattened_data=pd.json_normalize(results)
#       3 flattened_data
#
# NameError: name 'response' is not defined

# %%
import json
import requests

response = requests.get('https://api.github.com/users/Ironhack/repos')
results=response.json()
flattened_data=pd.json_normalize(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7548/1776985370.py in <module>
#       1 import json
# ----> 2 import requests
#       3
#       4 response = requests.get('https://api.github.com/users/Ironhack/repos')
#       5 results=response.json()
#
# ModuleNotFoundError: No module named 'requests'

# %%
flattened_data
# Out:
#            id                           node_id  \
# 0    75170096  MDEwOlJlcG9zaXRvcnk3NTE3MDA5Ng==
# 1   197550983  MDEwOlJlcG9zaXRvcnkxOTc1NTA5ODM=
# 2    57225749  MDEwOlJlcG9zaXRvcnk1NzIyNTc0OQ==
# 3    56848097  MDEwOlJlcG9zaXRvcnk1Njg0ODA5Nw==
# 4   122097049  MDEwOlJlcG9zaXRvcnkxMjIwOTcwNDk=
# 5    96100950  MDEwOlJlcG9zaXRvcnk5NjEwMDk1MA==
# 6    62580111  MDEwOlJlcG9zaXRvcnk2MjU4MDExMQ==
# 7   150108250  MDEwOlJlcG9zaXRvcnkxNTAxMDgyNTA=
# 8    44265416  MDEwOlJlcG9zaXRvcnk0NDI2NTQxNg==
# 9    56841990  MDEwOlJlcG9zaXRvcnk1Njg0MTk5MA==
# 10  134574029  MDEwOlJlcG9zaXRvcnkxMzQ1NzQwMjk=
# 11  115990443  MDEwOlJlcG9zaXRvcnkxMTU5OTA0NDM=
# 12   96104549  MDEwOlJlcG9zaXRvcnk5NjEwNDU0OQ==
# 13   86328286  MDEwOlJlcG9zaXRvcnk4NjMyODI4Ng==
# 14   34860891  MDEwOlJlcG9zaXRvcnkzNDg2MDg5MQ==
# 15  139946618  MDEwOlJlcG9zaXRvcnkxMzk5NDY2MTg=
# 16   85951144  MDEwOlJlcG9zaXRvcnk4NTk1MTE0NA==
# 17   97860064  MDEwOlJlcG9zaXRvcnk5Nzg2MDA2NA==
# ...

# %%
import json
import requests
response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/forks', auth=(Paul-Melin, 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))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3612/2218913308.py in <module>
#       1 import json
# ----> 2 import requests
#       3 response = requests.get('https://api.github.com/repos/ironhack-datalabs/databer0619/forks', auth=(Paul-Melin, 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))
#
# ModuleNotFoundError: No module named 'requests'

# %%
import requests
r=requests.get('https://xkcd.com/1830/')

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2656', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Mon, 06 Dec 2021 05:00:04 GMT', 'ETag': 'W/"61ad98d4-1ae0"', 'Expires': 'Mon, 06 Dec 2021 17:04:23 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 06 Dec 2021 16:59:23 GMT', 'Via': '1.1 varnish', 'Age': '0', 'X-Served-By': 'cache-cdg20728-CDG', 'X-Cache': 'MISS', 'X-Cache-Hits': '0', 'X-Timer': 'S1638809963.075800,VS0,VE103', 'Vary': 'Accept-Encoding'}

# %%
r.headers['Expires']
# Out:
# 'Mon, 06 Dec 2021 17:04:23 GMT'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: ISS Solar Transit 2</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script>\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="ISS Solar Transit 2">\n<meta property="og:url" content="https://xkcd.com/1830/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/iss_solar_transit_2_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div id="top
# ...

# %%
receive=requests.get('https://imgs.xkcd.com/comics/iss_solar_transit_2.png')
with open(r'C:\Users\paul\Downloads\image.png','wb') as f:
    f.write(receive.content)

# %%
import requests
r=requests.get('https://httpbin.org/get')
r.headers
# Out:
# {'Date': 'Mon, 06 Dec 2021 16:59:49 GMT', 'Content-Type': 'application/json', 'Content-Length': '309', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
import requests
ploads={'things':2, 'total':25}
r=requests.get('https://httpbin.org/get', params=ploads)
print(r.text)
print(r.url)
# Out:
# {
#   "args": {
#     "things": "2",
#     "total": "25"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae4188-12793513073d70543fa3b995"
#   },
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/get?things=2&total=25"
# }
#
# https://httpbin.org/get?things=2&total=25

# %%
import requests
pload={'Username':'Ksenia', 'password':'admin'}
r=requests.post('https://httpbin.org/post', data=pload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "Username": "Ksenia",
#     "password": "admin"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "30",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61ae418a-0d33681b4ac5415939cb48f1"
#   },
#   "json": null,
#   "origin": "195.134.167.217",
#   "url": "https://httpbin.org/post"
# }

# %%
import requests
pload={'Username':'Ksenia', 'password':'admin'}
r=requests.post('https://httpbin.org/post', data=pload)
r_dict=r.json()
print(r_dict['form'])
# Out:
# {'Username': 'Ksenia', 'password': 'admin'}

# %%
import tweepy

# %%
import tweepy
client = tweepy.Client(bearer_token = 'AAAAAAAAAAAAAAAAAAAAADZlWgEAAAAAtQ0e5x0oEDPVLa6JqXXbhHM2M1c%3DVCUU4PdrwO9BmAUVBaMQ18zYp5tMB3ZN6D0m62R6YpISBWd5ub')
query='from:Ironhack -is:retweet'
tweets=client.search_recent_tweets(query=query,tweet_fields=['context_annotations','created_at'], max_results=100)
for tweet in tweets.data:
    print(tweet.text)
    if len(tweet.context_annotations)>0:
        print(tweet.context_annotations)
# Out:
# Today is #Cybersecurity Day!🕵️‍♂️ With an almost 0% percent #unemployment rate + an estimated $6 trillion in #cybercrime damages a year globally, it’s safe to say that we need more of them! Read our #blogpost &amp; learn more about this opportunity-filled field! https://t.co/6LPAMcINP3 https://t.co/Cukf11ZZQv
# ...
